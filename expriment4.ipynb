# %%
from nltk.corpus import wordnet

word = "Good"
synonyms = []
antonyms = []

for syn in wordnet.synsets(word):
    for lemma in syn.lemmas():
        synonyms.append(lemma.name())

        if lemma.antonyms():
            antonyms.append(lemma.antonyms()[0].name())

print("Synonyms of", word, ":", set(synonyms))
print("Antonyms of", word, ":", set(antonyms))
# Out:
# Synonyms of Good : {'sound', 'honest', 'upright', 'dear', 'skillful', 'unspoilt', 'trade_good', 'goodness', 'soundly', 'safe', 'ripe', 'in_force', 'adept', 'beneficial', 'in_effect', 'unspoiled', 'proficient', 'commodity', 'salutary', 'right', 'skilful', 'good', 'respectable', 'thoroughly', 'undecomposed', 'honorable', 'near', 'practiced', 'expert', 'well', 'just', 'dependable', 'estimable', 'secure', 'full', 'serious', 'effective'}
# Antonyms of Good : {'evilness', 'ill', 'evil', 'bad', 'badness'}
